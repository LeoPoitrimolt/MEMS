# %%
import numpy as np
import matplotlib.pyplot as plt
x = []
y = []

with open('3_2_10K.txt', 'r') as f:
    line = f.readlines()
    x = [float(line.split()[0]) for line in lines]
    y = [float(line.split()[1]) for line in lines]


plt.plot(x ,y)
plt.xlabel('Frequency [Hz]')
plt.ylabel('Noise Level [V/Hz**1/2]')
plt.yscale('log')
plt.xscale('log')
plt.title('Noise Level regarding the frequency with a resistor of 10 kOhm')
plt.savefig('3_2_10K.png')


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = []
y = []

with open('3_3_1_shortcut.txt', 'r') as f1:
    line = f1.readlines()
    x = [float(line.split()[0]) for line in lines]
    y = [float(line.split()[1]) for line in lines]


plt.plot(x ,y)
plt.xlabel('Frequency [Hz]')
plt.ylabel('Noise Level [V/Hz**1/2]')
plt.yscale('log')
plt.xscale('log')
plt.title('Noise Level regarding the frequency with a shortcut in Input')
plt.savefig('3_3_1_shortcut.png')


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = []
y = []
f = []

with open('3_3_2_10M.txt', 'r') as f2:
    line = f2.readlines()
    x = [float(line.split()[0]) for line in lines]
    y = [float(line.split()[1]) for line in lines]


plt.plot(x ,y)
plt.xlabel('Frequency [Hz]')
plt.ylabel('Noise Level [V/Hz**1/2]')
plt.yscale('log')
plt.xscale('log')
plt.title('Noise Level regarding the frequency with a resistor of 10 MOhm')
plt.savefig('3_3_2_10M.png')


plt.show()
